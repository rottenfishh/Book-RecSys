# %%
import pandas as pd
import numpy as np
df = pd.read_csv("books_embeddings.csv")

# %%
def parse_embedding(embedding_str):
    """Convert the string of comma-separated floats into a NumPy array."""
    return np.array([float(x) for x in embedding_str.split(',')])

# %%
from sklearn.metrics.pairwise import cosine_similarity
import numpy as np

def find_closest_records(record, new_df, n=5):
    record_vector = parse_embedding(record['book_embedding']).reshape(1, -1)

    distances = []
    names = []

    length = new_df.shape[0]
    for index, row in new_df.iterrows():
        other_vector = parse_embedding(row['book_embedding']).reshape(1, -1)

        similarity = cosine_similarity(record_vector, other_vector)[0][0]

        distance = 1 - similarity

        distances.append(distance)
        names.append(row['name'])
        
        print(f'Progress: {index / length:.2%}', end='\r')

    sorted_indices = sorted(range(len(distances)), key=lambda k: distances[k])
    closest_names = [names[i] for i in sorted_indices[:n]]

    return closest_names

# %%
from sklearn.cluster import KMeans

def create_embeddings_list(df, embeddings):
    length = df.shape[0]
    for index, row in df.iterrows():
        vector = parse_embedding(row['book_embedding']).flatten()  
        embeddings.append(vector)  
        
        print(f'Progress: {index / length:.2%}', end='\r')
    return embeddings  


def create_cluster(embeddings, n_clusters = 50):
    embeddings_matrix = np.array(embeddings)  
    print("Embeddings matrix shape:", embeddings_matrix.shape)

    kmeans = KMeans(n_clusters= n_clusters, random_state=42)
    kmeans.fit(embeddings_matrix)

    cluster_labels = kmeans.labels_
    return cluster_labels, kmeans

# %%
embeddings = []
embeddings = create_embeddings_list(df, embeddings)
# Out:
# Progress: 100.00%

# %%
from sklearn.metrics.pairwise import cosine_similarity

def find_closest_records_clusters(record, new_df, cluster_labels, kmeans, n=5):
    
    record_vector = parse_embedding(record['book_embedding']).reshape(1, -1)

    record_cluster = kmeans.predict(record_vector)[0]
    
    same_cluster_df = new_df[np.array(cluster_labels) == record_cluster]
    
    distances = []
    names = []

    length = same_cluster_df.shape[0]
    for index, row in same_cluster_df.iterrows():
        other_vector = parse_embedding(row['book_embedding']).reshape(1, -1)
        
        similarity = cosine_similarity(record_vector, other_vector)[0][0]
        distance = 1 - similarity
        
        distances.append(distance)
        names.append(row['name'])

    sorted_indices = sorted(range(len(distances)), key=lambda k: distances[k])
    closest_names = [names[i] for i in sorted_indices[:n]]

    return closest_names

def find_closest_records_clusters2(record, new_df, cluster_labels, kmeans, n=5, n_clusters_to_search=2):
    record_vector = parse_embedding(record['book_embedding']).reshape(1, -1)
    record_cluster = kmeans.predict(record_vector)[0]

    record_centroid = kmeans.cluster_centers_[record_cluster].reshape(1, -1)
    centroid_distances = cosine_similarity(record_centroid, kmeans.cluster_centers_)[0]

    closest_cluster_indices = np.argsort(-centroid_distances)[:n_clusters_to_search + 1]
    
    closest_records_df = new_df[np.isin(cluster_labels, closest_cluster_indices)]
    
    distances = []
    names = []
    
    for index, row in closest_records_df.iterrows():
        other_vector = parse_embedding(row['book_embedding']).reshape(1, -1)
        similarity = cosine_similarity(record_vector, other_vector)[0][0]
        distance = 1 - similarity
        
        distances.append(distance)
        names.append(row['name'])
    
    # Sort by distance and retrieve the top n closest records
    sorted_indices = sorted(range(len(distances)), key=lambda k: distances[k])
    closest_names = [names[i] for i in sorted_indices[:n]]

    return closest_names

# %%
def find_records(indexes, n):
    result = []
    for i in indexes:
        result+=(find_closest_records(df.iloc[i], df, n))
    print(result)
    return result

# %%
def write_to_file(result):
    with open(r'records.txt', 'w') as fp:
        for item in result:
            # write each item on a new line
            fp.write("%s\n" % item)
        print('Done')

# %%
def how_many_match(indexes, cluster_labels, kmeans, result):
    n = 20
    clusters_result = []
    clusters_grouped_result = []
    for i in indexes:
        clusters_result+=(find_closest_records_clusters(df.iloc[i], df,  cluster_labels, kmeans, n))
        clusters_grouped_result+=(find_closest_records_clusters2(df.iloc[i], df,  cluster_labels, kmeans, n, 5))
    print(clusters_result)
    print(clusters_grouped_result)
    matches = [entry for entry in clusters_result if entry in result]
    matches2 = [entry for entry in clusters_grouped_result if entry in result]
    matches2_number = len(matches2)
    matches_number = len(matches)
    accuracy = matches_number / n
    accuracy2 = matches2_number / n
    return accuracy/len(indexes), accuracy2/len(indexes)

# %%
def find_best_number(numbers, indexes, result):
    accuracy = accuracy_grouped = 0
    best_accuracy = best_accuracy_grouped = 0
    best_number1 = -1
    best_number2 = -1
    accuracies = []
    accuracies2 = []
    for i in numbers:
        cluster_labels, kmeans = create_cluster(embeddings, n_clusters=i)
        accuracy, accuracy_grouped = how_many_match(indexes, cluster_labels, kmeans, result)
        if (accuracy > best_accuracy):
            best_accuracy = accuracy
            best_number1 = i
            cluster_labels_best, kmeans_best = cluster_labels, kmeans
        if (accuracy_grouped > best_accuracy_grouped):
            best_accuracy_grouped = accuracy_grouped
            best_number2 = i
        accuracies.append(accuracy)
        accuracies2.append(accuracy_grouped)
    
    return best_number1, best_number2, best_accuracy, best_accuracy_grouped, accuracies, accuracies2, cluster_labels_best, kmeans_best

# %%
numbers = [50, 55, 65]
indexes = [354, 1234, 4532, 9809, 9816, 3245]

# %%
result = find_records(indexes= indexes, n = 20)
write_to_file(result)
# Out:
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', "From mourning to morning: Healing in America's time of crisis", 'The Journey: How to live by Faith in an Uncertain World', 'Foundations for Christian Education in an Era of Change', 'Catch the Fire: The Toronto Blessing an Experience of Renewal and Revival', 'The Thorn In the Flesh: Hope for All Who Struggle With Impossible Conditions', 'Future Hope: A Jewish Christian Look at the End of the World', 'The Peacemaker: A Biblical Guide to Resolving Personal Conflict', "Revolution in World Missions: One Man's Journey to Change a Generation", "Tribulation to triumph: A mandate for today's church", "Hope in Times of Trouble (Seeking Answers in Life's Struggles)", "Hope When the World Falls Apart: Daniel and Revelation's Message of Hope", 'The Darkness and the Dawn: Empowered by the Tragedy and Triumph of the Cross', 'The Gift: A World Solution to Hunger and Poverty', 'Pueblo Intrigue: A Journey of Faith', 'Beyond Jungle Walls: Bringing Hope to the Forgotten Congo', 'At the edge of hope: Christian laity in paradox', 'THE STORY OF OLD GLORY: Cornerstones Of Freedom', 'Voices from the Heart: Inspiration for a Compassionate Future', 'Why Religion Matters: The Fate of the Human Spirit in an Age of Disbelief', 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Introduction to Information Systems: An End User/Enterprise Perspective', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', 'Readings', 'Living by Fiction', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession', 'The Best American Spiritual Writ ...
# Done

# %%
num1, num2, accuracy1, accuracy2, accuracies, accuracies2, cluster_labels_best, kmeans_best = find_best_number(numbers=numbers, indexes=indexes, result = result)
# Out:
# Embeddings matrix shape: (103063, 2771)
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', 'The Journey: How to live by Faith in an Uncertain World', 'Catch the Fire: The Toronto Blessing an Experience of Renewal and Revival', 'The Thorn In the Flesh: Hope for All Who Struggle With Impossible Conditions', 'Future Hope: A Jewish Christian Look at the End of the World', 'The Peacemaker: A Biblical Guide to Resolving Personal Conflict', "Tribulation to triumph: A mandate for today's church", "Hope in Times of Trouble (Seeking Answers in Life's Struggles)", "Hope When the World Falls Apart: Daniel and Revelation's Message of Hope", 'The Darkness and the Dawn: Empowered by the Tragedy and Triumph of the Cross', 'Pueblo Intrigue: A Journey of Faith', 'THE STORY OF OLD GLORY: Cornerstones Of Freedom', 'Voices from the Heart: Inspiration for a Compassionate Future', 'The Incredible Patience of God: Along the Road to Spiritual Maturity', "A Beacon in the Darkness : Reflecting God's Light in Today's World", "Armed and Dangerous: Facing Today's Battles with the Word of God", 'Signposts for the Future: Contemporary Issues Facing the Church', 'A Tapestry of Justice, Service and Unity: Local Ecumenism in the United States, 1950-2000', 'Blueprints for Life: Building on the Foundation of Christ', 'together: a story of shared vision', 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Introduction to Information Systems: An End User/Enterprise Perspective', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession', 'The Best American Spiritual Writing ...
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', 'The Journey: How to live by Faith in an Uncertain World', 'Catch the Fire: The Toronto Blessing an Experience of Renewal and Revival', 'The Thorn In the Flesh: Hope for All Who Struggle With Impossible Conditions', 'Future Hope: A Jewish Christian Look at the End of the World', 'The Peacemaker: A Biblical Guide to Resolving Personal Conflict', "Tribulation to triumph: A mandate for today's church", "Hope in Times of Trouble (Seeking Answers in Life's Struggles)", "Hope When the World Falls Apart: Daniel and Revelation's Message of Hope", 'The Darkness and the Dawn: Empowered by the Tragedy and Triumph of the Cross', 'Pueblo Intrigue: A Journey of Faith', 'Beyond Jungle Walls: Bringing Hope to the Forgotten Congo', 'THE STORY OF OLD GLORY: Cornerstones Of Freedom', 'Voices from the Heart: Inspiration for a Compassionate Future', 'The Incredible Patience of God: Along the Road to Spiritual Maturity', "A Beacon in the Darkness : Reflecting God's Light in Today's World", 'In the Eye of the Storm: A Celebration of Family & the Real Purpose of Home', "Armed and Dangerous: Facing Today's Battles with the Word of God", 'Life Without Limits: Powerful Truths That Bring Hope and Meaning', 'Signposts for the Future: Contemporary Issues Facing the Church', 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Introduction to Information Systems: An End User/Enterprise Perspective', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession', 'The Best American S ...
# Embeddings matrix shape: (103063, 2771)
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', 'The Journey: How to live by Faith in an Uncertain World', 'Catch the Fire: The Toronto Blessing an Experience of Renewal and Revival', 'The Thorn In the Flesh: Hope for All Who Struggle With Impossible Conditions', 'Future Hope: A Jewish Christian Look at the End of the World', 'The Peacemaker: A Biblical Guide to Resolving Personal Conflict', "Tribulation to triumph: A mandate for today's church", "Hope When the World Falls Apart: Daniel and Revelation's Message of Hope", 'The Darkness and the Dawn: Empowered by the Tragedy and Triumph of the Cross', 'Pueblo Intrigue: A Journey of Faith', 'Voices from the Heart: Inspiration for a Compassionate Future', 'The Incredible Patience of God: Along the Road to Spiritual Maturity', "A Beacon in the Darkness : Reflecting God's Light in Today's World", "Armed and Dangerous: Facing Today's Battles with the Word of God", 'Signposts for the Future: Contemporary Issues Facing the Church', 'Blueprints for Life: Building on the Foundation of Christ', 'Where God Was Born: A Journey by Land to the Roots of Religion', 'HABITATION OF DRAGONS : A BOOK OF HOPE ABOUT LIVING AS A CHRISTIAN', 'Healing Light: Thirty Messages of Love, Hope, and Courage', 'Abraham: A Journey to the Heart of Three Faiths', 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Oracle Essentials, 3e: Oracle Database 10g', 'Introduction to Information Systems: An End User/Enterprise Perspective', "The Internet's Coming of Age", 'The Unpredictable Certainty: Information Infrastructure Through 2000', 'Software Requirements (Dv-Best Practices)', 'Service-Oriented Architecture: A Field Guide to Integrating XML and Web Services (The Prentice Hall Service-Oriented Computing Series from Thomas Erl)', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', 'Readings', 'Living by Fiction', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Process ...
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', 'The Journey: How to live by Faith in an Uncertain World', 'Catch the Fire: The Toronto Blessing an Experience of Renewal and Revival', 'The Thorn In the Flesh: Hope for All Who Struggle With Impossible Conditions', 'Future Hope: A Jewish Christian Look at the End of the World', 'The Peacemaker: A Biblical Guide to Resolving Personal Conflict', "Revolution in World Missions: One Man's Journey to Change a Generation", "Tribulation to triumph: A mandate for today's church", "Hope in Times of Trouble (Seeking Answers in Life's Struggles)", "Hope When the World Falls Apart: Daniel and Revelation's Message of Hope", 'The Darkness and the Dawn: Empowered by the Tragedy and Triumph of the Cross', 'The Gift: A World Solution to Hunger and Poverty', 'Pueblo Intrigue: A Journey of Faith', 'THE STORY OF OLD GLORY: Cornerstones Of Freedom', 'Voices from the Heart: Inspiration for a Compassionate Future', 'The Incredible Patience of God: Along the Road to Spiritual Maturity', "A Beacon in the Darkness : Reflecting God's Light in Today's World", 'In the Eye of the Storm: A Celebration of Family & the Real Purpose of Home', "Armed and Dangerous: Facing Today's Battles with the Word of God", "In the Face of the Nations: Israel's Struggle for Peace", 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Introduction to Information Systems: An End User/Enterprise Perspective', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', 'Readings', 'Living by Fiction', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession' ...
# Embeddings matrix shape: (103063, 2771)
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', 'The Journey: How to live by Faith in an Uncertain World', 'Catch the Fire: The Toronto Blessing an Experience of Renewal and Revival', 'The Thorn In the Flesh: Hope for All Who Struggle With Impossible Conditions', 'Future Hope: A Jewish Christian Look at the End of the World', 'The Peacemaker: A Biblical Guide to Resolving Personal Conflict', "Tribulation to triumph: A mandate for today's church", "Hope When the World Falls Apart: Daniel and Revelation's Message of Hope", 'The Darkness and the Dawn: Empowered by the Tragedy and Triumph of the Cross', 'Pueblo Intrigue: A Journey of Faith', 'The Incredible Patience of God: Along the Road to Spiritual Maturity', "A Beacon in the Darkness : Reflecting God's Light in Today's World", "Armed and Dangerous: Facing Today's Battles with the Word of God", 'Signposts for the Future: Contemporary Issues Facing the Church', 'A Tapestry of Justice, Service and Unity: Local Ecumenism in the United States, 1950-2000', 'Blueprints for Life: Building on the Foundation of Christ', 'Where God Was Born: A Journey by Land to the Roots of Religion', 'HABITATION OF DRAGONS : A BOOK OF HOPE ABOUT LIVING AS A CHRISTIAN', 'Healing Light: Thirty Messages of Love, Hope, and Courage', 'Abraham: A Journey to the Heart of Three Faiths', 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Introduction to Information Systems: An End User/Enterprise Perspective', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession', 'The Bes ...
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', 'The Journey: How to live by Faith in an Uncertain World', 'Catch the Fire: The Toronto Blessing an Experience of Renewal and Revival', 'The Thorn In the Flesh: Hope for All Who Struggle With Impossible Conditions', 'Future Hope: A Jewish Christian Look at the End of the World', 'The Peacemaker: A Biblical Guide to Resolving Personal Conflict', "Tribulation to triumph: A mandate for today's church", "Hope When the World Falls Apart: Daniel and Revelation's Message of Hope", 'The Darkness and the Dawn: Empowered by the Tragedy and Triumph of the Cross', 'Pueblo Intrigue: A Journey of Faith', 'Beyond Jungle Walls: Bringing Hope to the Forgotten Congo', 'THE STORY OF OLD GLORY: Cornerstones Of Freedom', 'The Incredible Patience of God: Along the Road to Spiritual Maturity', "A Beacon in the Darkness : Reflecting God's Light in Today's World", 'In the Eye of the Storm: A Celebration of Family & the Real Purpose of Home', "Armed and Dangerous: Facing Today's Battles with the Word of God", "In the Face of the Nations: Israel's Struggle for Peace", 'Signposts for the Future: Contemporary Issues Facing the Church', "A Soldier in Search of Peace: An Inside Look at Israel's Strategy in the Middle East", 'Affect Destiny: The Book of Hope Story', 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Introduction to Information Systems: An End User/Enterprise Perspective', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession', 'The Best American Spiritual W ...
# Embeddings matrix shape: (103063, 2771)
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', "From mourning to morning: Healing in America's time of crisis", 'The Journey: How to live by Faith in an Uncertain World', 'The Thorn In the Flesh: Hope for All Who Struggle With Impossible Conditions', "Revolution in World Missions: One Man's Journey to Change a Generation", "Hope in Times of Trouble (Seeking Answers in Life's Struggles)", 'The Gift: A World Solution to Hunger and Poverty', 'Voices from the Heart: Inspiration for a Compassionate Future', 'In the Eye of the Storm: A Celebration of Family & the Real Purpose of Home', 'Leap of Reason: Managing to Outcomes in an Era of Scarcity', 'Life Without Limits: Powerful Truths That Bring Hope and Meaning', 'Love is the Target: An Answer for Troubled Americans, Today', "From Grief to Memories: A Workbook on Life's Significant Losses", 'The Foundation of Leadership: Enduring Principles to Govern Our Lives', 'together: a story of shared vision', 'Democracy is not enough;: A personal survey of the hungry world', 'The healing of a nation', 'In Pursuit of Peace: 21 Ways to Conquer Anxiety, Fear, and Discontentment (Meyer, Joyce)', 'Hearts of Gold: Four True Life Stories About Compassion', 'Journeynotes: Writing for Recovery and Spiritual Growth', 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Introduction to Information Systems: An End User/Enterprise Perspective', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession', 'The Best American Spiritual Writing 2006 (The Best American Series)', ...
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', "From mourning to morning: Healing in America's time of crisis", 'The Journey: How to live by Faith in an Uncertain World', 'The Thorn In the Flesh: Hope for All Who Struggle With Impossible Conditions', "Revolution in World Missions: One Man's Journey to Change a Generation", "Hope in Times of Trouble (Seeking Answers in Life's Struggles)", 'The Gift: A World Solution to Hunger and Poverty', 'Voices from the Heart: Inspiration for a Compassionate Future', 'In the Eye of the Storm: A Celebration of Family & the Real Purpose of Home', 'Leap of Reason: Managing to Outcomes in an Era of Scarcity', 'Life Without Limits: Powerful Truths That Bring Hope and Meaning', 'Love is the Target: An Answer for Troubled Americans, Today', "From Grief to Memories: A Workbook on Life's Significant Losses", 'The Foundation of Leadership: Enduring Principles to Govern Our Lives', 'together: a story of shared vision', 'Democracy is not enough;: A personal survey of the hungry world', 'The healing of a nation', 'In Pursuit of Peace: 21 Ways to Conquer Anxiety, Fear, and Discontentment (Meyer, Joyce)', 'Hearts of Gold: Four True Life Stories About Compassion', 'Journeynotes: Writing for Recovery and Spiritual Growth', 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Introduction to Information Systems: An End User/Enterprise Perspective', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession', 'The Best American Spiritual Writing 2006 (The Best American Series)', ...
# Embeddings matrix shape: (103063, 2771)
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', "From mourning to morning: Healing in America's time of crisis", 'Foundations for Christian Education in an Era of Change', 'Future Hope: A Jewish Christian Look at the End of the World', "Revolution in World Missions: One Man's Journey to Change a Generation", 'The Gift: A World Solution to Hunger and Poverty', 'Beyond Jungle Walls: Bringing Hope to the Forgotten Congo', 'At the edge of hope: Christian laity in paradox', 'Why Religion Matters: The Fate of the Human Spirit in an Age of Disbelief', 'Leap of Reason: Managing to Outcomes in an Era of Scarcity', "In the Face of the Nations: Israel's Struggle for Peace", 'In defense of creation : the nuclear crisis and a just peace', 'Signposts for the Future: Contemporary Issues Facing the Church', 'A Tapestry of Justice, Service and Unity: Local Ecumenism in the United States, 1950-2000', 'Democracy is not enough;: A personal survey of the hungry world', 'Washington: Christians in the corridors of power', 'In Pursuit of Peace: 21 Ways to Conquer Anxiety, Fear, and Discontentment (Meyer, Joyce)', 'The Company of the Committed: A Bold and Imaginative Re-thinking of the Strategy of the Church in Contemporary Life', "Changed Hearts: The Solution to America's Crime Problem", 'The Plight of the Church Traditionalist: A Last Apology', 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Designing Enterprise Applications with the J2EE¿ Platform (2nd Edition)', 'Core J2Ee Patterns: Best Practices and Design Strategies', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession', 'The Best Ame ...
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', "From mourning to morning: Healing in America's time of crisis", 'Foundations for Christian Education in an Era of Change', 'Future Hope: A Jewish Christian Look at the End of the World', "Revolution in World Missions: One Man's Journey to Change a Generation", 'The Gift: A World Solution to Hunger and Poverty', 'Beyond Jungle Walls: Bringing Hope to the Forgotten Congo', 'At the edge of hope: Christian laity in paradox', 'THE STORY OF OLD GLORY: Cornerstones Of Freedom', 'Why Religion Matters: The Fate of the Human Spirit in an Age of Disbelief', 'Leap of Reason: Managing to Outcomes in an Era of Scarcity', "In the Face of the Nations: Israel's Struggle for Peace", 'In defense of creation : the nuclear crisis and a just peace', 'Signposts for the Future: Contemporary Issues Facing the Church', "A Soldier in Search of Peace: An Inside Look at Israel's Strategy in the Middle East", 'A Tapestry of Justice, Service and Unity: Local Ecumenism in the United States, 1950-2000', 'Democracy is not enough;: A personal survey of the hungry world', 'Washington: Christians in the corridors of power', 'In Pursuit of Peace: 21 Ways to Conquer Anxiety, Fear, and Discontentment (Meyer, Joyce)', "When Heaven and Earth Changed Places: A Vietnamese Woman's Journey from War to Peace", 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Introduction to Information Systems: An End User/Enterprise Perspective', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession', ...

# %%
unique, counts = np.unique(cluster_labels_best, return_counts=True)
cluster_distribution = dict(zip(unique, counts))
print("Number of books in each cluster:", cluster_distribution)
# Out:
# Number of books in each cluster: {np.int32(0): np.int64(1947), np.int32(1): np.int64(4574), np.int32(2): np.int64(2019), np.int32(3): np.int64(3180), np.int32(4): np.int64(1219), np.int32(5): np.int64(6236), np.int32(6): np.int64(2471), np.int32(7): np.int64(3249), np.int32(8): np.int64(1584), np.int32(9): np.int64(1100), np.int32(10): np.int64(2237), np.int32(11): np.int64(2606), np.int32(12): np.int64(2602), np.int32(13): np.int64(2215), np.int32(14): np.int64(1056), np.int32(15): np.int64(2526), np.int32(16): np.int64(1839), np.int32(17): np.int64(5048), np.int32(18): np.int64(2337), np.int32(19): np.int64(3688), np.int32(20): np.int64(3187), np.int32(21): np.int64(3416), np.int32(22): np.int64(2384), np.int32(23): np.int64(999), np.int32(24): np.int64(6374), np.int32(25): np.int64(1897), np.int32(26): np.int64(2470), np.int32(27): np.int64(2363), np.int32(28): np.int64(1078), np.int32(29): np.int64(2155), np.int32(30): np.int64(2413), np.int32(31): np.int64(2430), np.int32(32): np.int64(2228), np.int32(33): np.int64(2954), np.int32(34): np.int64(3816), np.int32(35): np.int64(801), np.int32(36): np.int64(2632), np.int32(37): np.int64(3380), np.int32(38): np.int64(1711), np.int32(39): np.int64(642)}

# %%
print(num1,num2)
print(accuracy1, accuracy2)
print(numbers)
print(accuracies)
print(accuracies2)
# Out:
# 40 40
# 0.7916666666666666 0.9
# [40, 50, 55, 65, 75]
# [0.7916666666666666, 0.75, 0.7583333333333333, 0.75, 0.7000000000000001]
# [0.9, 0.8583333333333334, 0.8166666666666668, 0.7916666666666666, 0.7833333333333333]

# %%
import joblib
cluster_labels_df = pd.DataFrame(cluster_labels_best, columns=['Cluster'])
cluster_labels_df.to_csv('cluster_labels_best.csv', index=False)
joblib.dump(kmeans_best, 'kmeansbest_model.joblib')
# Out:
# ['kmeansbest_model.joblib']

# %%
find_closest_records_clusters(df.iloc[9809], df, cluster_labels_best, kmeans_best, 10)
# Out:
# ['Writing Was Everything',
#  "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others",
#  'Jafsie and John Henry: Essays',
#  'Walt Whitman: The Song of Himself',
#  'Penchants and Places: Essays and Criticism',
#  "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)",
#  'An American Procession',
#  'The Best American Spiritual Writing 2006 (The Best American Series)',
#  'Walk On The Wild Side',
#  'The Accidental Masterpiece: On the Art of Life and Vice Versa']

# %%
accuracy, accuracy_grouped = how_many_match(indexes, cluster_labels_best, kmeans_best, result)
# Out:
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', 'The Journey: How to live by Faith in an Uncertain World', 'Catch the Fire: The Toronto Blessing an Experience of Renewal and Revival', 'The Thorn In the Flesh: Hope for All Who Struggle With Impossible Conditions', 'Future Hope: A Jewish Christian Look at the End of the World', 'The Peacemaker: A Biblical Guide to Resolving Personal Conflict', "Tribulation to triumph: A mandate for today's church", "Hope in Times of Trouble (Seeking Answers in Life's Struggles)", "Hope When the World Falls Apart: Daniel and Revelation's Message of Hope", 'The Darkness and the Dawn: Empowered by the Tragedy and Triumph of the Cross', 'Pueblo Intrigue: A Journey of Faith', 'THE STORY OF OLD GLORY: Cornerstones Of Freedom', 'Voices from the Heart: Inspiration for a Compassionate Future', 'The Incredible Patience of God: Along the Road to Spiritual Maturity', "A Beacon in the Darkness : Reflecting God's Light in Today's World", "Armed and Dangerous: Facing Today's Battles with the Word of God", 'Signposts for the Future: Contemporary Issues Facing the Church', 'A Tapestry of Justice, Service and Unity: Local Ecumenism in the United States, 1950-2000', 'Blueprints for Life: Building on the Foundation of Christ', 'together: a story of shared vision', 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Introduction to Information Systems: An End User/Enterprise Perspective', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession', 'The Best American Spiritual Writing ...
# ['Operation Redemption: A Vision of Hope in an Age of Turmoil', 'The Journey: How to live by Faith in an Uncertain World', 'Catch the Fire: The Toronto Blessing an Experience of Renewal and Revival', 'The Thorn In the Flesh: Hope for All Who Struggle With Impossible Conditions', 'Future Hope: A Jewish Christian Look at the End of the World', 'The Peacemaker: A Biblical Guide to Resolving Personal Conflict', "Tribulation to triumph: A mandate for today's church", "Hope in Times of Trouble (Seeking Answers in Life's Struggles)", "Hope When the World Falls Apart: Daniel and Revelation's Message of Hope", 'The Darkness and the Dawn: Empowered by the Tragedy and Triumph of the Cross', 'Pueblo Intrigue: A Journey of Faith', 'Beyond Jungle Walls: Bringing Hope to the Forgotten Congo', 'THE STORY OF OLD GLORY: Cornerstones Of Freedom', 'Voices from the Heart: Inspiration for a Compassionate Future', 'The Incredible Patience of God: Along the Road to Spiritual Maturity', "A Beacon in the Darkness : Reflecting God's Light in Today's World", 'In the Eye of the Storm: A Celebration of Family & the Real Purpose of Home', "Armed and Dangerous: Facing Today's Battles with the Word of God", 'Life Without Limits: Powerful Truths That Bring Hope and Meaning', 'Signposts for the Future: Contemporary Issues Facing the Church', 'Distributed Computing Environments (McGraw-Hill Series on Computer Communications)', 'Client/Server Computing (James Martin/McGraw-Hill Productivity)', 'Distributed Computing and Client-Server', 'ATM: Theory and Application (Mcgraw-Hill Series on Computer Communications)', 'Tqm for Computer Software (Systems Design and Implementation)', 'Designing the User Interface: Strategies for Effective Human-Computer Interaction', 'Business Data Communications and Networking', 'Object Data Management: Object-Oriented and Extended Relational Database Systems', 'Software Architecture in Practice', 'The Rational Unified Process: An Introduction (2nd Edition)', 'The Rational Unified Process', 'Cmmi: Guidelines for Process Integration and Product Improvement', 'Distributed Systems: Concepts and Design (International Computer Science Series)', 'Systems Analysis & Design Methods', 'Software Project Management for Small to Medium Sized Projects', 'Ipsec: The New Security Standard for the Inter- net, Intranets, and Virtual Private Networks', 'Oracle Essentials, 3e: Oracle Database 10g', 'Internetworking with TCP/IP Vol. I: Principles, Protocols, and Architecture', 'Cisco IOS Configuration Fundamentals', 'Introduction to Information Systems: An End User/Enterprise Perspective', 'The Macmillan Writer: Rhetoric and Reader (Brief 4th Edition)', "The St. Martin's Guide to Writing", 'Prentice Hall Guide for College Writers, Full Edition with Handbook (5th Edition)', 'America Now: Short Readings from Recent Periodicals', 'The Contemporary Writer (Full)', 'So Long until Tomorrow: From Quaker Hill to Kathmandu', 'Exercises for the Everyday Writer: A Brief Reference', "Subjects/Strategies: A Writer's Reader", 'The Brief Holt Handbook', 'College Writing Skills with Readings, 5th Edition', 'The Brief Penguin Handbook (MLA Update)', 'Write Perfect Letters for Any Occasion', "The St. Martin's Guide to Writing: Short", 'The Bedford Handbook', "A Writer's Reference", 'Write Right!: A Desktop Digest of Punctuation, Grammar, and Style', "The Writer's Presence: A Pool of Readings", "The St. Martin's Handbook", 'Successful College Writing Brief: Skills, Strategies, Learning Styles', "Damn! Why Didn't I Write That? How Ordinary People are Raking in $100,000.00...or more Writing Nonfiction Books & How You Can Too!", 'Writing Was Everything', "The Style's the Man: Reflections on Proust, Fitzgerald, Wharton, Vidal, and Others", 'Jafsie and John Henry: Essays', 'Walt Whitman: The Song of Himself', 'Penchants and Places: Essays and Criticism', "Why Kerouac Matters: The Lessons of On the Road (They're Not What You Think)", 'An American Procession', 'The Best American S ...

# %%
print(accuracy, accuracy_grouped)
# Out:
# 0.7916666666666666 0.9
