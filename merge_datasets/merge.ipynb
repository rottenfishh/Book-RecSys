# %%
import pandas as pd

# %%
books_with_users = pd.read_csv("../Datasets/users/Books.csv")
books_without_users = pd.read_csv("../Datasets/BooksDataset.csv")
# Out:
# C:\Users\Ivans\AppData\Local\Temp\ipykernel_32512\2004526241.py:1: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   books_with_users = pd.read_csv("../Datasets/users/Books.csv")

# %%
books_with_users.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0195153448.0...
# ...

# %%
books_without_users.head()
# Out:
#                                                Title  \
# 0                                      Goat Brothers
# 1                                 The Missing Person
# 2                  Don't Eat Your Heart Out Cookbook
# 3  When Your Corporate Umbrella Begins to Leak: A...
# 4    Amy Spangler's Breastfeeding : A Parent's Guide
#
#                     Authors Description              Category  \
# 0          By Colton, Larry         NaN     History , General
# 1        By Grumbach, Doris         NaN     Fiction , General
# 2  By Piscatella, Joseph C.         NaN   Cooking , Reference
# 3         By Davis, Paul D.         NaN                   NaN
# 4          By Spangler, Amy         NaN                   NaN
#
#           Publisher                 Publish Date                    Price
# 0         Doubleday      Friday, January 1, 1993  Price Starting at $8.79
# 1  Putnam Pub Group        Sunday, March 1, 1981  Price Starting at $4.99
# ...

# %%
books_with_users["Title"] = books_with_users["Book-Title"]

# %%
mergedDf= pd.merge(books_with_users, books_without_users, on="Title", how="inner")

# %%
mergedDf.head()
# Out:
#          ISBN                                         Book-Title  \
# 0  0060973129                               Decision in Normandy
# 1  0393045218                             The Mummies of Urumchi
# 2  0399135782                             The Kitchen God's Wife
# 3  0399135782                             The Kitchen God's Wife
# 4  0425176428  What If?: The World's Foremost Military Histor...
#
#        Book-Author Year-Of-Publication                 Publisher_x  \
# 0     Carlo D'Este                1991             HarperPerennial
# 1  E. J. W. Barber                1999  W. W. Norton &amp; Company
# 2          Amy Tan                1991            Putnam Pub Group
# 3          Amy Tan                1991            Putnam Pub Group
# 4    Robert Cowley                2000    Berkley Publishing Group
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/0060973129.0...
# 1  http://images.amazon.com/images/P/0393045218.0...
# ...

# %%
mergedDf.shape
# Out:
# (37310, 15)

# %% [markdown]
# # 37310 records about same books
