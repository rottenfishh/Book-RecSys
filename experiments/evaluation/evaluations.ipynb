# %%
import sys
import os

PROJECT_ROOT = os.path.abspath(os.path.join(os.getcwd(), "..", ".."))
if PROJECT_ROOT not in sys.path:
    sys.path.insert(0, PROJECT_ROOT)

# %%
from src.evaluation import RecallKTitles
from src.models.modules import BookDescriptionEmbeddingSimilarity


k = 1000
recs_path = os.path.join(PROJECT_ROOT, "data/test_data/tests.json")
model_path = os.path.join(PROJECT_ROOT, "data/embeddings/books_embeddings_dataset.npy")
dataset_path = os.path.join(PROJECT_ROOT, "data/raw_data/LEHABOOKS.csv")
model = BookDescriptionEmbeddingSimilarity(model_path)
recs = RecallKTitles(k, recs_path, model, dataset_path)
recs.evaluate()
# Out:
# For book On the Road found 11 intersections with n = 1000, dataset have = 23
# For book On the Road found 6 intersections with 10 best recommendations and n = 1000, dataset have = 9
#
# --------------------------------------------------
#
# For book Island of the Blue Dolphins found 9 intersections with n = 1000, dataset have = 22
# For book Island of the Blue Dolphins found 4 intersections with 10 best recommendations and n = 1000, dataset have = 8
#
# --------------------------------------------------
#
# For book Life, the Universe, and Everything found 7 intersections with n = 1000, dataset have = 19
# For book Life, the Universe, and Everything found 4 intersections with 10 best recommendations and n = 1000, dataset have = 8
#
# --------------------------------------------------
#
# For book Back to the Stone Age found 8 intersections with n = 1000, dataset have = 13
# For book Back to the Stone Age found 2 intersections with 10 best recommendations and n = 1000, dataset have = 4
#
# --------------------------------------------------
#
# For book Fahrenheit 451 found 0 intersections with n = 1000, dataset have = 21
# For book Fahrenheit 451 found 0 intersections with 10 best recommendations and n = 1000, dataset have = 8
#
# --------------------------------------------------
#
# For book The Secret History found 3 intersections with n = 1000, dataset have = 13
# For book The Secret History found 2 intersections with 10 best recommendations and n = 1000, dataset have = 5
#
# --------------------------------------------------
#
# For book The Metamorphosis found 12 intersections with n = 1000, dataset have = 21
# For book The Metamorphosis found 4 intersections with 10 best recommendations and n = 1000, dataset have = 7
#
# --------------------------------------------------
#
# For book Lolita found 7 intersections with n = 1000, dataset have = 20
# For book Lolita found 1 intersections with 10 best recommendations and n = 1000, dataset have = 6
#
# --------------------------------------------------
#
# For book Island found 2 intersections with n = 1000, dataset have = 25
# For book Island found 1 intersections with 10 best recommendations and n = 1000, dataset have = 8
#
# --------------------------------------------------
#
# For book War and Peace found 16 intersections with n = 1000, dataset have = 26
# For book War and Peace found 8 intersections with 10 best recommendations and n = 1000, dataset have = 10
#
# --------------------------------------------------
#
# For book The Brothers Karamazov found 16 intersections with n = 1000, dataset have = 26
# For book The Brothers Karamazov found 8 intersections with 10 best recommendations and n = 1000, dataset have = 10
#
# --------------------------------------------------
#
# For book Crime and Punishment found 17 intersections with n = 1000, dataset have = 29
# For book Crime and Punishment found 4 intersections with 10 best recommendations and n = 1000, dataset have = 10
#
# --------------------------------------------------
#
# For book Anna Karenina found 1 intersections with n = 1000, dataset have = 27
# For book Anna Karenina found 0 intersections with 10 best recommendations and n = 1000, dataset have = 9
#
# --------------------------------------------------
#
# For book The Master and Margarita found 10 intersections with n = 1000, dataset have = 28
# For book The Master and Margarita found 4 intersections with 10 best recommendations and n = 1000, dataset have = 8
#
# --------------------------------------------------
#
# For book Midnight in the Garden of Good and Evil found 5 intersections with n = 1000, dataset have = 11
# For book Midnight in the Garden of Good and Evil found 3 intersections with 10 best recommendations and n = 1000, dataset have = 6
#
# --------------------------------------------------
#
# For book Every Breath You Take found 5 intersections with n = 1000, dataset have = 14
# For book Every Breath You Take found 3 intersections with 10 best recommendations and n = 1000, dataset have = 8
#
# --------------------------------------------------
#
# Good-Bye, My Little Ones not found
# For book A Civil Action found 4 intersections with n = 1000, dataset have = 10
# For book A Civil Action found 1 intersections with 10 best recommendations and n = 1000, dataset have = 2
#
# --------------------------------------------------
#
# For book Bitter Blood found 8 intersections with n = 1000, dataset have = 15
# For book Bitter Blood found 4 intersections with 10 best recommendations and n = 1000, dataset have = 7
#
# --------------------------------------------------
#
# For book Body Double found 8 intersections with n = 1000, dataset have = 11
# For book Body Double found 5 intersections with 10 best recommendations and n = 1000, dataset have = 6
#
# --------------------------------------------------
#
# For book Hush Little Babies found 8 intersections with n = 1000, dataset have = 16
# For book Hush Little Babies found 4 intersections with 10 best recommendations and n = 1000, dataset have = 7
#
# --------------------------------------------------
#
# For book Everything She Ever Wanted found 7 intersections with n = 1000, dataset have = 17
# For book Everything She Ever Wanted found 5 intersections with 10 best recommendations and n = 1000, dataset have = 7
#
# --------------------------------------------------
#
# For book In Cold Blood found 13 intersections with n = 1000, dataset have = 15
# For book In Cold Blood found 4 intersections with 10 best recommendations and n = 1000, dataset have = 5
#
# --------------------------------------------------
#
# For book The Middle Stories found 0 intersections with n = 1000, dataset have = 6
# For book The Middle Stories found 0 intersections with 10 best recommendations and n = 1000, dataset have = 5
#
# --------------------------------------------------
#
# For book Beloved found 3 intersections with n = 1000, dataset have = 17
# For book Beloved found 2 intersections with 10 best recommendations and n = 1000, dataset have = 9
#
# --------------------------------------------------
#
# For book Wild Animus found 9 intersections with n = 1000, dataset have = 24
# For book Wild Animus found 2 intersections with 10 best recommendations and n = 1000, dataset have = 5
#
# --------------------------------------------------
#
# For book Airframe found 5 intersections with n = 1000, dataset have = 23
# For book Airframe found 3 intersections with 10 best recommendations and n = 1000, dataset have = 5
#
# --------------------------------------------------
#
# For book Timeline found 6 intersections with n = 1000, dataset have = 13
# For book Timeline found 2 intersections with 10 best recommendations and n = 1000, dataset have = 5
#
# --------------------------------------------------
#
# For book Out of the Silent Planet found 4 intersections with n = 1000, dataset have = 25
# For book Out of the Silent Planet found 1 intersections with 10 best recommendations and n = 1000, dataset have = 8
#
# --------------------------------------------------
#
# For book Prague found 1 intersections with n = 1000, dataset have = 7
# For book Prague found 1 intersections with 10 best recommendations and n = 1000, dataset have = 4
#
# --------------------------------------------------
#
# Test was by 30 books
