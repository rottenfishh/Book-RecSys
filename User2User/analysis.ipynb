# %% [markdown]
# # Basic user 2 user

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Init and load the data

# %%
# Data paths
user_ratings_path = "../Datasets/Ratings.csv"
user_books_path = "../Datasets/Books.csv"
user_users_path = "../Datasets/Users.csv"

# Load data
user_ratings = pd.read_csv(user_ratings_path)
user_books = pd.read_csv(user_books_path)
user_users = pd.read_csv(user_users_path)


# Add ratings to the user_books
ratings_summary = user_ratings.groupby("ISBN")["Book-Rating"].agg(["count", "mean"])
ratings_summary = ratings_summary.rename(columns={"count": "Rating_Count", "mean": "Average_Rating"})
user_books = pd.merge(user_books, ratings_summary, on="ISBN", how="left")
user_books["Rating_Count"] = user_books["Rating_Count"].fillna(0) 
user_books["Average_Rating"] = user_books["Average_Rating"].fillna(user_books["Average_Rating"].median())

#Remove photos
user_books.drop(inplace=True, axis=1, columns=["Image-URL-S", "Image-URL-M", "Image-URL-L"])
# Out:
# C:\Users\Ivans\AppData\Local\Temp\ipykernel_22424\2952673529.py:8: DtypeWarning: Columns (3) have mixed types. Specify dtype option on import or set low_memory=False.
#   user_books = pd.read_csv(user_books_path)

# %%
model_path = "../models/books_embeddings_new_dataset.npy"

#Load the model
model = np.load(model_path, allow_pickle=True)

# %%
user_books.head(10)
# Out:
#          ISBN                                         Book-Title  \
# 0  0195153448                                Classical Mythology
# 1  0002005018                                       Clara Callan
# 2  0060973129                               Decision in Normandy
# 3  0374157065  Flu: The Story of the Great Influenza Pandemic...
# 4  0393045218                             The Mummies of Urumchi
# 5  0399135782                             The Kitchen God's Wife
# 6  0425176428  What If?: The World's Foremost Military Histor...
# 7  0671870432                                    PLEADING GUILTY
# 8  0679425608  Under the Black Flag: The Romance and the Real...
# 9  074322678X            Where You'll Find Me: And Other Stories
#
#             Book-Author Year-Of-Publication                   Publisher  \
# 0    Mark P. O. Morford                2002     Oxford University Press
# 1  Richard Bruce Wright                2001       HarperFlamingo Canada
# 2          Carlo D'Este                1991             HarperPerennial
# 3      Gina Bari Kolata                1999        Farrar Straus Giroux
# 4       E. J. W. Barber                1999  W. W. Norton &amp; Company
# 5               Amy Tan                1991            Putnam Pub Group
# 6         Robert Cowley                2000    Berkley Publishing Group
# 7           Scott Turow                1993                  Audioworks
# 8       David Cordingly                1996                Random House
# 9           Ann Beattie                2002                    Scribner
#
#    Rating_Count  Average_Rating
# 0           1.0        0.000000
# 1          14.0        4.928571
# 2           3.0        5.000000
# 3          11.0        4.272727
# 4           1.0        0.000000
# 5          33.0        4.212121
# 6           5.0        1.600000
# 7           3.0        2.666667
# 8           1.0        0.000000
# 9           1.0        5.000000

# %%
user_books.head(1)
# Out:
#          ISBN           Book-Title         Book-Author Year-Of-Publication  \
# 0  0195153448  Classical Mythology  Mark P. O. Morford                2002
#
#                  Publisher                                        Image-URL-S  \
# 0  Oxford University Press  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/0195153448.0...
#
#                                          Image-URL-L
# 0  http://images.amazon.com/images/P/0195153448.0...

# %%
model["book_embedding"] = model["book_embedding"].apply(
    lambda embedding_str: np.array([float(x) for x in embedding_str.split(',')]))

# %%
model.shape
# Out:
# (103063, 2)

# %%
model["Book-Title"] = model["name"]
model.drop(columns=["name"], inplace=True, axis=1)
model.head()
# Out:
#                                       book_embedding  \
# 0  [0.012158381752669811, 0.12222578376531601, -0...
# 1  [0.10339748859405518, 0.01937180384993553, -0....
# 2  [0.5171516537666321, 0.41499367356300354, -0.1...
# 3  [0.1548372060060501, -0.16966335475444794, -0....
# 4  [0.05578360706567764, -0.17162510752677917, -0...
#
#                                           Book-Title
# 0                                      Goat Brothers
# 1                                 The Missing Person
# 2                  Don't Eat Your Heart Out Cookbook
# 3  When Your Corporate Umbrella Begins to Leak: A...
# 4    Amy Spangler's Breastfeeding : A Parent's Guide

# %%
books = pd.merge(model, user_books, on="Book-Title", how="inner")
books.drop(axis=1, columns=["Image-URL-S", "Image-URL-M", "Image-URL-L"], inplace=True)

# %%
books.head()
# Out:
#                                       book_embedding  \
# 0  [0.012158381752669811, 0.12222578376531601, -0...
# 1  [0.5171516537666321, 0.41499367356300354, -0.1...
# 2  [0.1548372060060501, -0.16966335475444794, -0....
# 3  [0.0917205661535263, 0.13396266102790833, -0.1...
# 4  [-0.15954221785068512, 0.1715346723794937, 0.0...
#
#                                           Book-Title        ISBN  \
# 0                                      Goat Brothers  038524407X
# 1                  Don't Eat Your Heart Out Cookbook  089480488X
# 2  When Your Corporate Umbrella Begins to Leak: A...  091576590X
# 3  The Foundation of Leadership: Enduring Princip...  096582070X
# 4                         Journey Through Heartsongs  0786869429
#
#              Book-Author Year-Of-Publication             Publisher  \
# 0           Larry Colton                1993       Doubleday Books
# 1   Joseph C. Piscatella                1983        Workman Pub Co
# 2          Paul D. Davis                1991  National Press Books
# 3         Strom Thurmond                1997       Excalibur Press
# 4  Mattie J. T. Stepanek                2002        Hyperion Press
#
#    Rating_Count  Average_Rating
# 0           1.0            0.00
# 1           1.0            0.00
# 2           1.0            0.00
# 3           2.0            5.00
# 4           8.0            2.25

# %%
ratings_and_embeddings = pd.merge(model, user_books, on="Book-Title", how="inner")

# %%
ratings_and_embeddings.head()
# Out:
#                                       book_embedding  \
# 0  [0.012158381752669811, 0.12222578376531601, -0...
# 1  [0.5171516537666321, 0.41499367356300354, -0.1...
# 2  [0.1548372060060501, -0.16966335475444794, -0....
# 3  [0.0917205661535263, 0.13396266102790833, -0.1...
# 4  [-0.15954221785068512, 0.1715346723794937, 0.0...
#
#                                           Book-Title        ISBN  \
# 0                                      Goat Brothers  038524407X
# 1                  Don't Eat Your Heart Out Cookbook  089480488X
# 2  When Your Corporate Umbrella Begins to Leak: A...  091576590X
# 3  The Foundation of Leadership: Enduring Princip...  096582070X
# 4                         Journey Through Heartsongs  0786869429
#
#              Book-Author Year-Of-Publication             Publisher  \
# 0           Larry Colton                1993       Doubleday Books
# 1   Joseph C. Piscatella                1983        Workman Pub Co
# 2          Paul D. Davis                1991  National Press Books
# 3         Strom Thurmond                1997       Excalibur Press
# 4  Mattie J. T. Stepanek                2002        Hyperion Press
#
#                                          Image-URL-S  \
# 0  http://images.amazon.com/images/P/038524407X.0...
# 1  http://images.amazon.com/images/P/089480488X.0...
# 2  http://images.amazon.com/images/P/091576590X.0...
# 3  http://images.amazon.com/images/P/096582070X.0...
# 4  http://images.amazon.com/images/P/0786869429.0...
#
#                                          Image-URL-M  \
# 0  http://images.amazon.com/images/P/038524407X.0...
# 1  http://images.amazon.com/images/P/089480488X.0...
# 2  http://images.amazon.com/images/P/091576590X.0...
# 3  http://images.amazon.com/images/P/096582070X.0...
# 4  http://images.amazon.com/images/P/0786869429.0...
#
#                                          Image-URL-L  Rating_Count  \
# 0  http://images.amazon.com/images/P/038524407X.0...           1.0
# 1  http://images.amazon.com/images/P/089480488X.0...           1.0
# 2  http://images.amazon.com/images/P/091576590X.0...           1.0
# 3  http://images.amazon.com/images/P/096582070X.0...           2.0
# 4  http://images.amazon.com/images/P/0786869429.0...           8.0
#
#    Average_Rating
# 0            0.00
# 1            0.00
# 2            0.00
# 3            5.00
# 4            2.25

# %%
user_ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276729  052165615X            3
# 4   276729  0521795028            6

# %%
user_ratings = user_ratings.merge(ratings_and_embeddings, on='ISBN', how='inner')

def weighted_embedding(user_data):
    ratings = user_data['Book-Rating'].to_numpy()
    embeddings = np.vstack(user_data['book_embedding'])

    weighted_sum = np.sum(ratings[:, np.newaxis] * embeddings, axis=0)
    total_weight = np.sum(ratings)

    return weighted_sum / total_weight


weighted_embeddings = user_ratings.groupby('User-ID').apply(weighted_embedding).reset_index()


weighted_embeddings.columns = ['User-ID', 'weighted_embedding']
# Out:
# C:\Users\Ivans\AppData\Local\Temp\ipykernel_42344\1660163742.py:15: RuntimeWarning: invalid value encountered in divide
#   return weighted_sum / total_weight
# C:\Users\Ivans\AppData\Local\Temp\ipykernel_42344\1660163742.py:19: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   weighted_embeddings = user_ratings.groupby('User-ID').apply(weighted_embedding).reset_index()
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[22], line 24
#      21 # Результат
#      22 weighted_embeddings.columns = ['User-ID', 'weighted_embedding']  # Переименуем столбец
# ---> 24 weighted_embedding.head()
#
# AttributeError: 'function' object has no attribute 'head'

# %%
user_ratings.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276725  034545104X            0
# 1   276726  0155061224            5
# 2   276727  0446520802            0
# 3   276727  0446520802            0
# 4   276727  0446520802            0
#
#                                     book_embedding_x  Book-Title_x  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2  [-0.11909034103155136, -0.08501839637756348, 0...  The Notebook
# 3  [-0.11909034103155136, -0.08501839637756348, 0...  The Notebook
# 4  [-0.11090793460607529, -0.1434868574142456, 0....  The Notebook
#
#      Book-Author_x Year-Of-Publication_x   Publisher_x  \
# 0              NaN                   NaN           NaN
# 1              NaN                   NaN           NaN
# 2  Nicholas Sparks                  1996  Warner Books
# 3  Nicholas Sparks                  1996  Warner Books
# 4  Nicholas Sparks                  1996  Warner Books
#
#                                        Image-URL-S_x  \
# 0                                                NaN
# 1                                                NaN
# 2  http://images.amazon.com/images/P/0446520802.0...
# 3  http://images.amazon.com/images/P/0446520802.0...
# 4  http://images.amazon.com/images/P/0446520802.0...
#
#                                        Image-URL-M_x  ...  \
# 0                                                NaN  ...
# 1                                                NaN  ...
# 2  http://images.amazon.com/images/P/0446520802.0...  ...
# 3  http://images.amazon.com/images/P/0446520802.0...  ...
# 4  http://images.amazon.com/images/P/0446520802.0...  ...
#
#                                     book_embedding_y  Book-Title_y  \
# 0                                                NaN           NaN
# 1                                                NaN           NaN
# 2  [-0.11909034103155136, -0.08501839637756348, 0...  The Notebook
# 3  [-0.11090793460607529, -0.1434868574142456, 0....  The Notebook
# 4  [-0.11909034103155136, -0.08501839637756348, 0...  The Notebook
#
#      Book-Author_y Year-Of-Publication_y   Publisher_y  \
# 0              NaN                   NaN           NaN
# 1              NaN                   NaN           NaN
# 2  Nicholas Sparks                  1996  Warner Books
# 3  Nicholas Sparks                  1996  Warner Books
# 4  Nicholas Sparks                  1996  Warner Books
#
#                                        Image-URL-S_y  \
# 0                                                NaN
# 1                                                NaN
# 2  http://images.amazon.com/images/P/0446520802.0...
# 3  http://images.amazon.com/images/P/0446520802.0...
# 4  http://images.amazon.com/images/P/0446520802.0...
#
#                                        Image-URL-M_y  \
# 0                                                NaN
# 1                                                NaN
# 2  http://images.amazon.com/images/P/0446520802.0...
# 3  http://images.amazon.com/images/P/0446520802.0...
# 4  http://images.amazon.com/images/P/0446520802.0...
#
#                                        Image-URL-L_y Rating_Count_y  \
# 0                                                NaN            NaN
# 1                                                NaN            NaN
# 2  http://images.amazon.com/images/P/0446520802.0...          116.0
# 3  http://images.amazon.com/images/P/0446520802.0...          116.0
# 4  http://images.amazon.com/images/P/0446520802.0...          116.0
#
#   Average_Rating_y
# 0              NaN
# 1              NaN
# 2         4.060345
# 3         4.060345
# 4         4.060345
#
# [5 rows x 23 columns]

# %%
merged = pd.merge(user_ratings, ratings_and_embeddings, on="Book-Title", how="inner")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_42344\838773330.py in ?()
# ----> 1 merged = pd.merge(user_ratings, ratings_and_embeddings, on="Book-Title", how="inner")
#
# d:\programm_files\anaconda\Lib\site-packages\pandas\core\reshape\merge.py in ?(left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, copy, indicator, validate)
#     166             validate=validate,
#     167             copy=copy,
#     168         )
#     169     else:
# --> 170         op = _MergeOperation(
#     171             left_df,
#     172             right_df,
#     173             how=how,
#
# d:\programm_files\anaconda\Lib\site-packages\pandas\core\reshape\merge.py in ?(self, left, right, how, on, left_on, right_on, left_index, right_index, sort, suffixes, indicator, validate)
#     790             self.right_join_keys,
#     791             self.join_names,
#     792             left_drop,
#     793             right_drop,
# --> 794         ) = self._get_merge_keys()
#     795
#     796         if left_drop:
#     797             self.left = self.left._drop_labels_or_levels(left_drop)
#
# d:\programm_files\anaconda\Lib\site-packages\pandas\core\reshape\merge.py in ?(self)
#    1306                     if lk is not None:
#    1307                         # Then we're either Hashable or a wrong-length arraylike,
#    1308                         #  the latter of which will raise
#    1309                         lk = cast(Hashable, lk)
# -> 1310                         left_keys.append(left._get_label_or_level_values(lk))
#    1311                         join_names.append(lk)
#    1312                     else:
#    1313                         # work-around for merge_asof(left_index=True)
#
# d:\programm_files\anaconda\Lib\site-packages\pandas\core\generic.py in ?(self, key, axis)
#    1907             values = self.xs(key, axis=other_axes[0])._values
#    1908         elif self._is_level_reference(key, axis=axis):
#    1909             values = self.axes[axis].get_level_values(key)._values
#    1910         else:
# -> 1911             raise KeyError(key)
#    1912
#    1913         # Check for duplicates
#    1914         if values.ndim > 1:
#
# KeyError: 'Book-Title'

# %%
user_ratings.groupby("User-ID")["Book-Rating"].agg(["count", "mean"])
# Out:
#          count      mean
# User-ID
# 2            1  0.000000
# 7            1  0.000000
# 8           18  2.166667
# 9            3  2.000000
# 10           2  3.000000
# ...        ...       ...
# 278846       2  4.000000
# 278849       4  2.250000
# 278851      23  3.956522
# 278852       1  8.000000
# 278854       8  5.250000
#
# [105283 rows x 2 columns]

# %%
users = pd.merge(user_ratings, books, on="ISBN", how="inner")
users.head()
# Out:
#    User-ID        ISBN  Book-Rating  \
# 0   276727  0446520802            0
# 1   276727  0446520802            0
# 2   276744  038550120X            7
# 3   276746  0425115801            0
# 4   276746  0425115801            0
#
#                                       book_embedding       Book-Title  \
# 0  [-0.11909034103155136, -0.08501839637756348, 0...     The Notebook
# 1  [-0.11090793460607529, -0.1434868574142456, 0....     The Notebook
# 2  [0.08054692298173904, 0.2433057427406311, 0.24...  A Painted House
# 3  [-0.31400224566459656, 0.030658535659313202, 0...        Lightning
# 4  [-0.22315305471420288, -0.2346639186143875, 0....        Lightning
#
#        Book-Author Year-Of-Publication                 Publisher  \
# 0  Nicholas Sparks                1996              Warner Books
# 1  Nicholas Sparks                1996              Warner Books
# 2     JOHN GRISHAM                2001                 Doubleday
# 3   Dean R. Koontz                1996  Berkley Publishing Group
# 4   Dean R. Koontz                1996  Berkley Publishing Group
#
#    Rating_Count  Average_Rating
# 0         116.0        4.060345
# 1         116.0        4.060345
# 2         184.0        3.336957
# 3         134.0        2.529851
# 4         134.0        2.529851
